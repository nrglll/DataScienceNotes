# %% [markdown]
# <p id="top"></p>

# %% [markdown]
# # DATA CLEANING AND MANIPULATION WITH PANDAS

# %% [markdown]
# This notebook includes data cleaning and manipulation notes with Pandas codes.

# %% [markdown]
# CONTEXT
#
# <ul>
#     <li><a href="#1">Cleaning Data</a>
#         <ul>
#             <li><a href="#2"> Diagnose Data for Cleaning </a></li>
#             <li><a href="#3"> Exploratory Data Analysis (EDA) </a></li>
#             <li><a href="#4"> Visual Exploratory Data Analysis </a></li>
#             <li><a href="#5"> Tidy and Pivoting Data </a></li>
#             <li><a href="#6"> Concatenating Data </a></li>
#              <li><a href="#7"> Data Types </a></li>
#             <li><a href="#8"> Missing Data and Testing with Assert </a></li>
#         </ul>
#     </li>
# </ul>
#
# <ul>
#     <li><a href="#9">Pandas Foundation</a>
#         <ul>
#             <li><a href="#10"> Review of Pandas </a></li>
#             <li><a href="#11"> Building Data Frames From Scratch </a></li>
#             <li><a href="#12"> Visual Exploratory Data Analysis </a></li>
#             <li><a href="#13"> Statistical Exploratory Data Analysis </a></li>
#             <li><a href="#14"> Indexing Pandas Time Series </a></li>
#             <li><a href="#15"> Resampling Pandas Time Series </a></li>
#         </ul>
#     </li>
# </ul>
#
# <ul>
#     <li><a href="#16"> Manipulating Data Frames with Pandas </a>
#         <ul>
#             <li><a href="#17"> Indexing Data Frames </a></li>
#             <li><a href="#18"> Slicing Data Frames </a></li>
#             <li><a href="#19"> Filtering Data Frames </a></li>
#             <li><a href="#20"> Transforming Data Frames </a></li>
#             <li><a href="#21"> Index Objects and Labeled Data </a></li>
#             <li><a href="#22"> Hierarchical Indexing </a></li>
#             <li><a href="#23"> Pivoting Data Frames </a></li>
#             <li><a href="#24"> Stacking-Unstacking Data Frames </a></li>
#             <li><a href="#25"> Melting Data Frames </a></li>
#             <li><a href="#26"> Cathegoricals and Groupby </a></li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <p id="1"></p> <br>
#
# ## Cleaning Data

# %% [markdown]
# <p id="2"></p> <br>
#
# ### Diagnose Data for Cleaning

# %% [markdown]
# We need to diagnose and clean data before exploring.
# Unclean data:
# - Column name inconsistency like upper-lower case letter or space between words
# - Missing data
# - Different language
#
# <br>We will use head, tail, columns, shape and info methods to diagnose data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("pokemon.csv")
data.head() # head shows first 5 rows
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail() # tail shows last 5 rows
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data.columns # columns gives column names
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %% [markdown]
# <p id="3"></p> <br>
#
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# In statistics, exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods. Firstly, we will look at some terms.
# - **value_counts():** Frequency counts

# %%
# Let's look frequency of pokemon types
print(data["Type 1"].value_counts(dropna=False))
# If there is null values, this method counts them also. 
# As can be seen below, there are 112 water pokemon and 70 grass pokemon etc.
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# **Outliers:** The value that is considerably higher or lower from the rest of the data.
# * Lets say value at 75% is Q3 and value at 25% is Q1.
# * Outlier are smaller than Q1 - 1.5(Q3-Q1) and bigger than Q3 + 1.5(Q3-Q1). (Q3-Q1) = IQR
# <br>We will use **describe()** method. Describe method includes:
# * count: number of entries
# * mean: average of entries
# * std: standart deviation
# * min: minimum entry
# * 25%: first quartile
# * 50%: median or second quartile
# * 75%: third quartile
# * max: maximum entry
#
# <br> What is **quartile**?
#
# * 1,4,5,6,8,9,11,12,13,14,15,16,17
# * The **median** is the number that is in **middle** of the sequence. In this case it would be 11.
#
# * The lower quartile is the median in between the smallest number and the median i.e. in between 1 and 11, which is 6.
# * The upper quartile, you find the median between the median and the largest number i.e. between 11 and 17, which will be 14 according to the question above.

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# <p id="4"></p> <br>
#
# ### Visual Exploratory Data Analysis
# <br> Box plots: Visualize basic statistics like outliers, min/max or quantiles.

# %%
# For example: compare attack of pokemons that are legendary  or not
# Black line at top is max
# Blue line at top is 75%
# Green line is median (50%)
# Blue line at bottom is 25%
# Black line at bottom is min
# There are no outliers
data.boxplot(column = "Attack", by = "Legendary")
plt.show()

# %% [markdown]
# <p id="5"></p> <br>
#
# ### Tidy and Pivoting Data

# %% [markdown]
# **Tidy Data:** <br>
# We tidy data with **melt()**. <br>
# We generally use melt() for visualisation. <br>
# Describing melt is confusing. Therefore lets make example to understand it.

# %%
# Firstly I create a new data from pokemons data to explain melt more easily. 
data_new = data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Let's melt
# id_vars : what we do not wish to melt
# value_vars : what we want to melt
melted = pd.melt(frame = data_new, id_vars = "Name", value_vars = ["Attack", "Defense"])
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %% [markdown]
# **Pivoting data:** <br>
# Reverse of melting data.

# %%
melted.pivot(index="Name", columns="variable", values="value")
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %% [markdown]
# <p id="6"></p> <br>
#
# ### Concatenating Data
#
# <br> We can concatenate two data frames.

# %%
# Firstlt let's create two data frames.

# %%
data1 = data.head()
data2 = data.tail()

conc_data_row = pd.concat([data1,data2], axis=0, ignore_index=True) 
# axis = 0 adds data in row (vertical)
# ignore_index = True mean create new index (for this example 0-9)
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data1 = data["Attack"].head()
data2 = data["Defense"].head()

conc_data_col = pd.concat([data1, data2], axis =1) # axis = 1 mean concatanete horizontally
# ignore_index = False for this example. It is default, so it is ok if we don't write.
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %% [markdown]
# <p id="7"></p> <br>
#
# ### Data Types

# %% [markdown]
# There are 5 basic data types:
# - object(string)
# - boolean
# - integer
# - float
# - categorical
#
# <br> We can make conversion data types like from str to categorical or from int to float.
# <br> **astype()** method can be used for changing data types in data frame.
#
# <br> Why is category important:
# - make data frame smaller in memory
# - can be utilized for anlaysis especially for sklearn(we will learn later)

# %%
# Example of conversion
print(int(0.8))
print(float(8))
# Out:
# 0
# 8.0

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# lets convert object(str) to categorical and int to float for our data frame.
data["Type 1"] = data["Type 1"].astype("category")
data["Speed"] = data["Speed"].astype("float")

data.dtypes

# As you can see Type 1 is converted from object to categorical
# And Speeds converted from int to float
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %% [markdown]
# <p id="8"></p> <br>
#
# ### Missing Data and Testing with Assert
#
# <br> If we encounter with missing data, what we can do:
# * leave as it is
# * drop them with **dropna()**
# * fill missing value with **fillna()**
# * fill missing values with test statistics like mean
#
# <br>**Assert statement:** check that you can turn on or turn off when you are done with your testing of the program

# %%
# Lets look at does pokemon data have nan value
data.info()
# As you can see there are 800 entries. However Type 2 has 414 non-null object so it has 386 null object.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 65.0+ KB

# %%
data["Type 2"].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Water        14
# Ghost        14
# Rock         14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data["Type 2"].dropna(inplace=True) 
# inplace = True mean drop non values and save to the data frame
# In other words, we do not assign it to new variable. Changes automatically assigned to data
# If nothing turns, it worked.

# %%
#  Lets check with assert statement
# Assert statement:
assert 1==1 # return nothing because it is true

# %%
# In order to run all code, we need to make this line comment
# assert 1==2 # return error because it is false

# %%
assert data['Type 2'].notnull().all() # returns nothing because we drop nan values

# %%
data["Type 2"] = data["Type 2"].fillna("Empty", inplace=True)

# %%
# # With assert statement we can check a lot of thing. For example
# assert data.columns[1] == 'Name'
# assert data.Speed.dtypes == np.int

# %% [markdown]
# <p id="9"></p> <br>
#
# ## Pandas Foundation

# %% [markdown]
# <p id="10"></p> <br>
#
# ### Review of Pandas
#
# <br> We will go deeper in pandas.
# * single column = series
# * NaN = not a number
# * dataframe.values = numpy

# %% [markdown]
# <p id="11"></p> <br>
#
# ### Building Data Frames From Scratch
#
# - We can build data frames from csv as we did earlier.
# - Also we can build dataframe from dictionaries
#     * **zip() method:** This function returns a list of tuples, where the n-th tuple contains the n-th element from each of the argument sequences or iterables.
# - Adding new column
# - **Broadcasting:** Create new column and assign a value to entire column. (The term broadcasting refers to how numpy treats arrays with different Dimension during arithmetic operations which lead to certain constraints, the smaller array is broadcast across the larger array so that they have compatible shapes.)

# %%
# data frames from dictionary
country = ["Spain", "France"]
population = [11, 12]
list_label = ["Country", "Population"]
list_col = [country, population]
zipped = list(zip(list_label, list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   Country  Population
# 0   Spain          11
# 1  France          12

# %%
# Add new columns

df["Capital"] = ["Madrid", "Paris"]
df
# Out:
#   Country  Population Capital
# 0   Spain          11  Madrid
# 1  France          12   Paris

# %%
# Broadcasting

df["Income"] = 0
df
# Out:
#   Country  Population Capital  Income
# 0   Spain          11  Madrid       0
# 1  France          12   Paris       0

# %% [markdown]
# <p id="12"></p> <br>
#
# ### Visual Exploratory Data Analysis
#
# * Plot
# * Subplot
# * Histogram:
#     * bins: number of bins
#     * range(tuble): min and max values of bins
#     * normed(boolean): normalize or not
#     * cumulative(boolean): compute cumulative distribution

# %%
# Plotting all data

data1 = data.loc[:,["Attack", "Defense", "Speed"]]
data1.plot()
plt.show()
# this plot very confusing and hard to understand

# %%
# Let's use subplot for create simple plot

data1.plot(subplots = True)
plt.show()

# %%
# scatter plot
data1.plot(kind="scatter", x = "Attack", y= "Defense")
plt.show()

# %%
# histogram

data1.plot(kind="hist", y="Defense", bins=50, range= (0, 250), density=True)
# range is y axis range
# density means use normalized values (values between 0 and 1)
plt.show()

# %%
# Histogram subplot with cumulative and non-cumulative 

fig, axis = plt.subplots(nrows=2, ncols=1)
data1.plot(kind="hist", y = "Defense", bins=50, range = (0, 250), density=True, ax = axis[0])
data1.plot(kind="hist", y = "Defense", bins=50, range=(0,250), density=True, ax = axis[1], cumulative = True)
plt.savefig("cumulative_hist.png")
plt.show()

# %% [markdown]
# <p id="13"></p> <br>
#
# ### Statistical Exploratory Data Analysis
#
# I already explained it at previous parts. However lets look at one more time.
# * count: number of entries
# * mean: average of entries
# * std: standart deviation
# * min: minimum entry
# * 25%: first quantile
# * 50%: median or second quantile
# * 75%: third quantile
# * max: maximum entry

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass   None  45      49       49       65
# 1      2         Ivysaur    Grass   None  60      62       63       80
# 2      3        Venusaur    Grass   None  80      82       83      100
# 3      4   Mega Venusaur    Grass   None  80     100      123      122
# 4      5      Charmander     Fire   None  39      52       43       60
# ..   ...             ...      ...    ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   None  50     100      150      100
# 796  797    Mega Diancie     Rock   None  50     160      110      160
# 797  798  Hoopa Confined  Psychic   None  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   None  80     160       60      170
# 799  800       Volcanion     Fire   None  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# <p id="14"></p> <br>
#
# ### Indexing Pandas Time Series
#
# * datetime = object
# * parse_dates(boolean): Transform date to ISO 8601 (yyyy-mm-dd hh:mm:ss ) format

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) 
# As you can see date is string, however we want it to be datetime object
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
import warnings 
warnings.filterwarnings("ignore") # just closing warnings

# In order to practice, lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["Date"] = datetime_object

# let's make date as index
data2 = data2.set_index("Date")
data2
# Out:
#             #           Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# Date
# 1992-01-10  1      Bulbasaur  Grass   None  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass   None  60      62       63       80
# 1992-03-10  3       Venusaur  Grass   None  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass   None  80     100      123      122
# 1993-03-16  5     Charmander   Fire   None  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# Date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
# How we can select according to our date index
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# #                      5
# Name          Charmander
# Type 1              Fire
# Type 2              None
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object
#             #           Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# Date
# 1992-03-10  3       Venusaur  Grass   None  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass   None  80     100      123      122
# 1993-03-16  5     Charmander   Fire   None  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# Date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %% [markdown]
# <p id="15"></p> <br>
#
# ### Resampling Pandas Time Series
#
# * Resampling: statistical method over different time intervals
#     * Needs string to specify frequency like "M" = month or "A" = year
# * Downsampling: reduce date time rows to slower frequency like from daily to weekly
# * Upsampling: increase date time rows to faster frequency like from daily to hourly
# * Interpolate: Interpolate values according to different methods like ‘linear’, ‘time’ or index’
#     * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html

# %%
data2.resample("A").mean() # find years and their mean for every value
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# Date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# Date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample("M").mean() # find months and their mean for every value
# As you can see there are a lot of nan because data2 does not include all months
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
# In real life (data is real. Not created from us like data2) we can solve this problem with interpolate
# We can interpolate from mean() (Turkish=arasını doldurmak)
data2.resample("M").mean().interpolate() # default is linear, but you can change method
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# Date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# ...

# %% [markdown]
# <p id="16"></p> <br>
#
# ## Manipulating Data Frames with Pandas

# %% [markdown]
# <p id="17"></p> <br>
#
# ### Indexing Data Frames
#
# * Indexing using square brackets
# * Using column attribute and row label
# * Using loc accessor
# * Selecting only some columns

# %%
data = data.set_index("#")
data.head()
# Out:
#             Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass   None  45      49       49       65       65   45.0
# 2        Ivysaur  Grass   None  60      62       63       80       80   60.0
# 3       Venusaur  Grass   None  80      82       83      100      100   80.0
# 4  Mega Venusaur  Grass   None  80     100      123      122      120   80.0
# 5     Charmander   Fire   None  39      52       43       60       50   65.0
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
# indexing using square bracket
data["HP"][1]
# Out:
# 45

# %%
data.HP[1]
# Out:
# 45

# %%
# using loc accessor 
data.loc[1, ["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
# selecting only some columns
data[["HP", "Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 4    80     100
# 5    39      52
# ..   ..     ...
# 796  50     100
# 797  50     160
# 798  80     110
# 799  80     160
# 800  80     110
#
# [800 rows x 2 columns]

# %% [markdown]
# <p id="18"></p> <br>
#
# ### Slicing Data Frames
#
# <br> The difference of selecting columns:
#     - series and data frames
# * Slicing and indexing series
# * Reverse slicing
# * From something to end

# %%
# The difference of selecting columns: series and data frames
print(type(data["HP"]))     # series
print(type(data[["HP"]]))   # data frames
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Slicing and indexing series
data.loc[1:10, "HP":"Defense"]   # 10 and Defense are inclusive
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
# Reverse slicing
data.loc[10:1:-1, "HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
# from something to end
data.loc[1:10, "Speed":]
# Out:
#     Speed  Generation  Legendary
# #
# 1    45.0           1      False
# 2    60.0           1      False
# 3    80.0           1      False
# 4    80.0           1      False
# 5    65.0           1      False
# 6    80.0           1      False
# 7   100.0           1      False
# 8   100.0           1      False
# 9   100.0           1      False
# 10   43.0           1      False

# %% [markdown]
# <p id="19"></p> <br>
#
# ### Filtering Data Frames
# - Creating boolean series
# - Combining filters
# - Filtering column based others

# %%
# Creating boolean series
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122  Chansey  Normal   None  250       5        5       35      105   50.0
# 262  Blissey  Normal   None  255      10       10       75      135   55.0
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False

# %%
# Combining filters
first_filter = data.HP > 150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal   None  250       5        5       35      105   50.0
# 262    Blissey  Normal   None  255      10       10       75      135   55.0
# 352    Wailord   Water   None  170      90       45       90       45   60.0
# 656  Alomomola   Water   None  165      75       80       40       45   65.0
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
# Filtering column based others
data.HP[data.Speed<15]
# Out:
# #
# 231     20
# 360     45
# 487     50
# 496    135
# 659     44
# Name: HP, dtype: int64

# %% [markdown]
# <p id="20"></p> <br>
#
# ### Transforming Data Frames
# * Basic python functions
# * Lambda function: to apply arbitrary python function to every element
# * Defining column using other columns

# %%
# Basic python functions (apply())
def div(n):
    return n/2
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Or We can use lambda function (apply())
data.HP.apply(lambda n: n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Defining column using other columns
data["total_power"] = data.Attack + data.Defense 
data.head()
# Out:
#             Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass   None  45      49       49       65       65   45.0
# 2        Ivysaur  Grass   None  60      62       63       80       80   60.0
# 3       Venusaur  Grass   None  80      82       83      100      100   80.0
# 4  Mega Venusaur  Grass   None  80     100      123      122      120   80.0
# 5     Charmander   Fire   None  39      52       43       60       50   65.0
#
#    Generation  Legendary  total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %% [markdown]
# <p id="21"></p> <br>
#
# ### Index Objects and Labeled Data
# index: sequence of label

# %%
# our index name is this:
print(data.index.name)
# Out:
# #

# %%
# let's change it
data.index.name = "index_name"
data.head()
# Out:
#                      Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass   None  45      49       49       65
# 2                 Ivysaur  Grass   None  60      62       63       80
# 3                Venusaur  Grass   None  80      82       83      100
# 4           Mega Venusaur  Grass   None  80     100      123      122
# 5              Charmander   Fire   None  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 1                65   45.0           1      False           98
# 2                80   60.0           1      False          125
# 3               100   80.0           1      False          165
# 4               120   80.0           1      False          223
# 5                50   65.0           1      False           95

# %%
# Overwrite index
# if we want to modify index we need to change all of them.
data.head()
# first copy of our data to data3 then change index 
data3 = data.copy()
# lets make index start from 100. It is not remarkable change but it is just example
data3.index = range(100,900,1)
data3.head()
# Out:
#               Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass   None  45      49       49       65       65
# 101        Ivysaur  Grass   None  60      62       63       80       80
# 102       Venusaur  Grass   None  80      82       83      100      100
# 103  Mega Venusaur  Grass   None  80     100      123      122      120
# 104     Charmander   Fire   None  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100   45.0           1      False           98
# 101   60.0           1      False          125
# 102   80.0           1      False          165
# 103   80.0           1      False          223
# 104   65.0           1      False           95

# %%
# We can make one of the column as index. I actually did it at the beginning of manipulating data frames with pandas section
# It was like this
# data= data.set_index("#")
# also we can use 
# data.index = data["#"]

# %% [markdown]
# <p id="22"></p> <br>
#
# ### Hierarchical Indexing
# Setting indexing

# %%
# lets read data frame one more time to start from beginning
data = pd.read_csv("pokemon.csv")
data.head()
# As you can see there is index. However we want to set one or more column to be index
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Setting index : type 1 is outer type 2 is inner index
data1 =data.set_index(["Type 1","Type 2"])
data1.head(50)
# data1.loc["Fire","Flying"] # howw to use indexes
# Out:
#                   #              Name   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1   Type 2
# Grass    Poison   1         Bulbasaur   45      49       49       65       65
#          Poison   2           Ivysaur   60      62       63       80       80
#          Poison   3          Venusaur   80      82       83      100      100
#          Poison   4     Mega Venusaur   80     100      123      122      120
# Fire     NaN      5        Charmander   39      52       43       60       50
#          NaN      6        Charmeleon   58      64       58       80       65
#          Flying   7         Charizard   78      84       78      109       85
#          Dragon   8  Mega Charizard X   78     130      111      130       85
#          Flying   9  Mega Charizard Y   78     104       78      159      115
# Water    NaN     10          Squirtle   44      48       65       50       64
#          NaN     11         Wartortle   59      63       80       65       80
# ...

# %% [markdown]
# <p id="23"></p> <br>
#
# ### Pivoting Data Frames
# Pivoting: reshape tool

# %%
# Let's create new data frame for example of pivoting
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
#pivoting
df.pivot(index="treatment", columns = "gender", values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %% [markdown]
# <p id="24"></p> <br>
#
# ### Stacking-Unstacking Data Frames
# - Dealing with multi label indexes
# - level: position of unstacked index
# - swaplevel: change inner and outer level index position

# %%
df1 = df.set_index(["treatment","gender"])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
# Lets unstack it
# level determines indexes
df1.unstack(level=0) # level = 0 mean unstack first column (index) (df1[0]) ("treatment")
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1) # unstack df1[1] ("gender")
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
# change inner and outer level index position
df2 = df1.swaplevel(0,1) # it changed position of "treatment" and "gender"
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %% [markdown]
# <p id="25"></p> <br>
#
# ### Melting Data Frames
# Reverse of pivoting

# %%
# pivoting
# df.pivot(index="treatment", columns = "gender", values="response")

# melting
pd.melt(df, id_vars="treatment",value_vars=["age", "response"]) # age:variable, response: value
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %% [markdown]
# <p id="26"></p> <br>
#
# ### Cathegoricals and Groupby

# %%
# according to treatment take means of other features
df.groupby("treatment").mean()   # mean is aggregation / reduction method
# there are other methods like sum, std,max or min
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby("treatment").age.mean()
# Out:
# treatment
# A     9.5
# B    68.5
# Name: age, dtype: float64

# %%
df.groupby("treatment")[["age", "response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# as you can see gender is object
# However if we use groupby, we can convert it categorical data. 
# Because categorical data uses less memory, speed up operations like groupby
#df["gender"] = df["gender"].astype("category")
#df["treatment"] = df["treatment"].astype("category")
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      object
#  1   gender     4 non-null      object
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %% [markdown]
# <p><a href="#top">This link goes to the top</a></p>
